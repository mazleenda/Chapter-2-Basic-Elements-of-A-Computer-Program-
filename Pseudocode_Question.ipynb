# %% [markdown]
# <a href="https://colab.research.google.com/github/mazleenda/Chapter-2-Basic-Elements-of-A-Computer-Program-/blob/main/Pseudocode_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exercise 2.1 – Pseudocode**
#
# Question - Write a pseudocode to calculate the area of a rectangle.
#
# The program should:
#
# Read the length.
# Read the width.
# Calculate the area.
# Display the area.
# Task
#
# Write the complete pseudocode.

# %% [markdown]
# **Exercise 2.2 – Pseudocode**
#
# Question- Write a pseudocode to calculate the average mark of three subjects.
#
# Write the complete pseudocode.

# %% [markdown]
# **Exercise 2.3  –Pseudocode**
# Question- Write a pseudocode to calculate the Body Mass Index (BMI).
#
# The formula is:
#
# BMI = Weight (kg) / Height² (m²)
#
# Task
#
# Write the complete pseudocode.
